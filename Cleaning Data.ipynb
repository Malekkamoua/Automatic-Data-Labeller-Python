# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %%
# !pip install unrar
# Out:
# Collecting unrar
#   Downloading https://files.pythonhosted.org/packages/bb/0b/53130ccd483e3db8c8a460cb579bdb21b458d5494d67a261e1a5b273fbb9/unrar-0.4-py3-none-any.whl
# Installing collected packages: unrar
# Successfully installed unrar-0.4

# %%
# !unrar x "/content/gdrive/My Drive/PFA DATA/Copy of data.rar"

# %%
#Displaying folders' names
import os

directory_list = list()
for root, dirs, files in os.walk("/content/data", topdown=False):
    for name in dirs:
        directory_list.append(os.path.join(root, name))

print (directory_list)
# Out:
# ['/content/data/aaaai.org', '/content/data/adai.uw.edu', '/content/data/addictionrehab.us.com', '/content/data/acog.org', '/content/data/19january2017snapshot.epa.gov', '/content/data/acfas.org', '/content/data/accidentlawillinois.com', '/content/data/adaa.org', '/content/data/aasm.org', '/content/data/adventureswl.com', '/content/data/abc15.com', '/content/data/1800theeagle.com', '/content/data/academia.edu', '/content/data/2ndchance.info', '/content/data/adhdfraud.com', '/content/data/aarp.org', '/content/data/ada.gov', '/content/data/aapd.org', '/content/data/addictionsearch.com', '/content/data/acefitness.org', '/content/data/acaai.org', '/content/data/aerzteblatt.de', '/content/data/aau.edu', '/content/data/advancednaturalwellness.net', '/content/data/123helpme.com', '/content/data/addictionresource.com', '/content/data/acatoday.org', '/content/data/addictionhope.com', '/content/data/accesalabs.com', '/content/data/adwdiabetes.com', '/content/data/abim.org', '/content/data/aacp.com', '/content/data/academon.com', '/content/data/abcnews.go.com', '/content/data/accessdata.fda.gov', '/content/data/ada.org', '/content/data/ada-cmrglobalgroupservices.com', '/content/data/ada-ksw.com', '/content/data/aafp.org', '/content/data/actiononhearingloss.org.uk', '/content/data/addictionblog.org', '/content/data/acsm.org', '/content/data/acadc.org', '/content/data/activebeat.com', '/content/data/aafa.org', '/content/data/addictioncenter.com', '/content/data/advocatehealth.com', '/content/data/acconec.com', '/content/data/academic.oup.com', '/content/data/addictionsandrecovery.org', '/content/data/3dprintingindustry.com', '/content/data/activator.com', '/content/data/aademeeting.org', '/content/data/abilitychiro.com', '/content/data/addictions.org', '/content/data/aaep.org', '/content/data/activebeat.co', '/content/data/advancedwaterfilters.com', '/content/data/aap.org', '/content/data/164andmore.com', '/content/data/adrianmathews.com', '/content/data/aaia.ca', '/content/data/aboutkidshealth.ca']

# %%
#adding .html to all files
all_files = 0
for root, dirs, files in os.walk("/content/data", topdown=False):
    all_files += len(files)
    for file in files:
        base_path, ext = os.path.splitext(os.path.join(root, file))

        if not ext:
 
            os.rename(base_path, base_path + ".html")
print(all_files)
# Out:
# 135526

# %%
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.request

def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True

 
def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

errors = 0
for root, dirs, files in os.walk("/content/data", topdown=False):
    for dir in dirs[1:]:

      allfiles = os.listdir('/content/data/'+dir)
      files = [ fname for fname in allfiles if fname.endswith('.html')]
      for file in files:

        single_filename = file

        # try:
         
        file1 = open(r'/content/data/'+dir+'/'+file, "r",encoding=None, errors=None, newline=None,closefd=True, opener=None)
        contenu = file1.read()
        filename = file1.name

        html = str(contenu)

        newfilename = os.path.splitext(single_filename)[0]
  
        # Save clean file 
        title = 'clean_data/'+newfilename+'.txt'
        file = open(title, "w") 
        file.write(text_from_html(html)) 
        file.close() 

        #encoding error blocking the process
        except :
          errors += 1
          print('error')
          continue
         
         

print("all work is done :)")

# %%
all_new_files = 0
for root, dirs, files in os.walk("/content/clean_data", topdown=False):
    all_new_files += len(files)

print('All files: '+str(all_files))
print('new files: '+str(all_new_files))
# Out:
# All files: 135516
# new files: 130238

# %%
print('Errors catched: '+str(errors))
print('All files: '+str(all_files))
pourcentage = (round((errors/all_files * 100), 3))
print('Loss: '+str(pourcentage)+ ' %')
# Out:
# Errors catched: 3742
# All files: 135516
# Loss: 2.761 %

# %%
# !zip -r /content/clean_data /content/clean_data

# %%
# mount it
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# copy it there
# !cp "/content/clean_data.zip" "/content/gdrive/My Drive/PFA DATA/Clean_data/Untitled folder"
# Out:
# Mounted at /content/gdrive
