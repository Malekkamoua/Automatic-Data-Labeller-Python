# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Extract 1
from zipfile import ZipFile

with ZipFile('/content/gdrive/MyDrive/PFA DATA/preprocessed_data/preprocessed_data_part1.zip', 'r') as zipObj:
  zipObj.extractall()

print('Done extracting folder.')
# Out:
# Done extracting folder.

# %%
path = "/content/content/content/preprocessed_data_part1"

# %%
import os

all_files = 0
for root, dirs, files in os.walk(path, topdown=False):
    all_files += len(files)

print(all_files)
# Out:
# 2000

# %%
#Read extracted folders
import os

for root, dirs, files in os.walk(path, topdown=False):
  print(files)
# Out:
# ['9fa5c610-9835-477c-939c-9c62d33cdc32.txt', '1fbbbdb2-a9ac-4b7b-ae70-c4cb7c0fd816.txt', 'b5c2bf7a-b7f3-458b-a520-0f3e76bcbcf9.txt', '0109a624-db1b-42ed-87e8-53335c72c0fe.txt', 'bc7a661b-1c0d-4f75-acb2-84b58a6fd9a0.txt', 'f74831fa-5fa7-4e9b-b795-e7851657adaf.txt', '6ba85280-8b8a-4665-97c1-fd5ced835e0c.txt', '47b0b085-6bfb-4b5d-9eec-2c1336033a72.txt', '93515948-f5f6-42b5-a723-ec198c41774c.txt', 'cca02b6b-3d44-4b9c-96cf-cba06b065115.txt', '2f5814a0-f077-4c4f-90cf-1e61f6e286cc.txt', '1a0d79a4-90f4-4193-bbe2-4aff8d918458.txt', '5edf1051-a5d5-4eb1-ac36-987e8d869d0d.txt', '02869e49-2eea-4a53-9ec5-b4a95a1390d0.txt', '9b983605-59d7-4239-9eba-cf674861957b.txt', 'da58f064-6180-47c0-be54-621899e7c6b4.txt', '12521b40-a829-4513-972e-ca5f039be83e.txt', 'e7ffc66c-31bb-4d59-b934-465eba65aab3.txt', '48fcb6d5-5c0e-48ba-8f05-55d97a3fa20d.txt', 'cd76f3bd-5ecc-436a-8fbe-edb9cf0052af.txt', '7492c4aa-aa97-4093-b28e-29140b57a67d.txt', '23693222-c5ef-494d-bfd4-7907a0418c0e.txt', '6ac949b2-390d-4a6b-934c-e0d8
# ...

# %%
pip install nltk==3.4.5
# Out:
# ...
#      |████████████████████████████████| 1.5MB 5.5MB/s
# ...
#   Created wheel for nltk: filename=nltk-3.4.5-cp37-none-any.whl size=1449906 sha256=d13f233748f7f82c048f9b49da17484c9f80de3857041886766b9d6fc5288a2c
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
# Successfully built nltk
# ...
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import re
import string
import nltk  
from nltk.tokenize import word_tokenize

# %%
# iterate through all files
doc = []
for file in os.listdir(path):
    if file.endswith(".txt"):
        file_path = f"{path}/{file}"
        with open(file_path, 'r') as f:
          doc.append(f.readline())

doc

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(doc)

true_k = 10
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)

order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()

for i in range(true_k):
  print("Cluster %d:" % i),
  for ind in order_centroids[i, :20]:
    print(" %s" % terms[ind])

# %%
print("Prediction")
X = vectorizer.transform(["To respond to the pandemic, the government has pledged a serious health sector reform… and the rebuilding of the public health system"])
predicted = model.predict(X)
print(predicted)

# %%
import nltk 
nltk.download('words')
words = set(nltk.corpus.words.words())

# %%
sent =  'account khaled hosseinis kite runner essay example khaled hosseinis kite runner essay example length word doublespaced page rating better essay open document essay preview discrimination bigotry class structure present afghan society outlined well khaled hosseini ’ novel kite runner character experience witness one aforementioned characteristic society incessant use discrimination novel significant many reason prominent element society still present today kite runner help student understand unjust life fortunate far removed circumstance three dominant point story discrimination bigotry class structure woman viewed treated hazaras seen inferior difference amir ’ old neighbourhood versus rest afghanistan woman treated equal men afghanistan expected sit quietly men life want many woman kite runner victim injustice deal harsh consequence making mistake soraya amir ’ wife experience consequence endlessly trivial mistake made teenager girl soraya ran away afghan man drug afghan virginia talked soraya forced live terrible reputation ever since year later soraya ’ cousin ’ wedding overheard conversation two middleaged woman “ boy well marry cousin ” one woman remarked soraya broke tear car later “ ’ fing unfair son go nightclub looking meat get girlfriend pregnant kid wedlock one say middle paper afghanistan one may ever know ’ like ‘ real ’ world population afghanistan experienced many hardship daily life novel kite runner khaled hosseini brilliantly depicts life really like afghanistan privileged boy ’ point view horror realizes afghanistan despite grew nice place discrimination bigotry everpresent afghan society one exempt brutality taliban restriction breached taliban publicly hang ‘ stone ’ otherwise execute offender discrimination bigotry class structure always likely always around afghan life afghanistan become place death destruction people live constantly fearful life read full essay click button view complete essay speech term paper research paper need writing help get feedback grammar clarity concision logic instantly check paper » essay guaranteed kite runner khaled hosseini essay journey give u ability explore world insightful perspective matured perspective developed feature journey significantly affect u crossing red sea postcard peter skrzynecki kite runner khaled hosseini represent feature crossing red sea demonstrates concept stripped innocence healing process whilst journey persistence past journey postcard portrays confronting lingering attribute incomplete journey tag khaled hosseini kite runner emotion better essay word page kite runner khaled hosseini essay influential people one ’ life frequently impact way person develops shape person become word conveyed action delivered two people affect way person ’ life develops alter positive negative way novel kite runner khaled hosseini author depicts amir main character greatly impacted influenced shaped character phase amir reader announced early stage novel different amir end novel tag khaled hosseini kite runner writing better essay word page essay khaled hosseini kite runner character shaped genetics culture personal experience case khaled hosseini ’ kite runner complex character amir mainly shaped circumstance life amir life episode diverse experience result experience character shaped throughout kite runner story young boy named amir living kabul progress throughout lifespan undergoes stage happiness sorrow confusion reach adulthood tag khaled hosseini kite runner kite runner better essay word page khaled hosseini kite runner essay novel kite runner author khaled hosseini creates sincere narrative following disturbing life young afghan body amir transition adolescence adulthood amir must face various challenge journey life including difficult relationship closest implication russian invasion afghanistan account difficult relationship baba amir constantly seeking way gain attention gratification matter cost tag khaled hosseini kite runner hazara people better essay word page kite runner khaled hosseini essay novel kite runner essay novel kite runner khaled hosseini several major theme one theme stand redemption theme shown thought action protagonist novel amir seeking redemption betraying childhood best friend halfbrother hassan due amir ’ cowardice hassan ’ rape feel guilty committing vilest sin afghan culture “ one last chance make decision tag khaled hosseini kite runner kite runner better essay word page kite runner khaled hosseini essay example trial struggle daily life kite runner khaled hosseini show reader friendship two boy change grow afghani culture throughout novel conflict two character expose reader vast difference social position well depth personal relationship dedication kite runner expose difference amir hassan exploring action daily life situation requiring bravery dedication selflessness tag khaled hosseini kite runner kite runner better essay word page kite runner khaled hosseini essay may khaled hosseini published first book kite runner tale amir afghan boy trying atone mistake childhood many different stylistic choice made writing use fragment change point view overwhelming imagery sometimes three choice show one single paragraph add character overall novel hosseini used fragment often particularly single verb meant emphasize part writing tag khaled hosseini kite runner kite runner better essay word page essay kite runner khaled hosseini personal liberation redemption occurs person encounter difficulty point life redeems later thus discovering purpose life khaled hosseini ’ novel “ kite runner ” protagonist amir know thing mistake novel struggle atone mistake throughout stage amir ’ life strives redemption liberation comparing young boy ’ struggle walt kowalski displeased man film “ gran torino ” seems implausible story correlate due journey towards liberation redemption tag khaled hosseini kite runner kite runner better essay word page kite runner khaled hosseini essay relationship father son bond something extremely strong could break kite runner khaled hosseini many significant fatherson relationship three main relationship novel baba amir hassan sohrab amir sohrab fatherson relationship important novel determine many key event outcome start relationship baba amir ’ really called relationship tag khaled hosseini kite runner kite runner better essay word page essay khaled hosseinis kite runner khaled hosseinis kite runner boy named amir think anyways life ho dad big expensive home afganistan mom died giving birth servent named ali son named hassan age good manythings except know read wri tag summary kite runner khaled hosseini free essay word page popular essay world religion chapter summary quality education america effect acid mold similarity difference gilgamesha dn enkindu experience kidney disease silverado hospice leonardo da vinci painter inventor scientific theorist free essay free essay af free essay gl free essay mq free essay rz additional popular essay excellent essay essay topic plagiarism donate paper company term service privacy dmca contact faq copyright © helpmecom right reserved'
sent = " ".join(w for w in nltk.wordpunct_tokenize(sent) if w.lower() in words or not w.isalpha())
print(sent)

# %%
from gensim import corpora

# be sure to split sentence before feed into Dictionary
dataset = [d.split() for d in doc]

dictionary = corpora.Dictionary(dataset)
corpus = [dictionary.doc2bow(text) for text in dataset]

# %%
from gensim import models
model = models.ldamodel.LdaModel(corpus, num_topics=20, id2word=dictionary, passes=15)

topics = model.print_topics(num_words=3)
for topic in topics:
    print(topic)

# %%
pip install pyLDAvis==2.1.2

# %%
import pyLDAvis.gensim
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(model, corpus, dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2     -0.017133  0.062167       1        1  13.108859
# 1      0.211719 -0.102477       2        1  12.085685
# 15     0.084394  0.007417       3        1   9.024241
# 5      0.040662  0.050664       4        1   7.624723
# 16     0.078111  0.046367       5        1   6.998099
# 6     -0.022062  0.144836       6        1   6.715277
# 14    -0.108119  0.056819       7        1   6.615760
# 4      0.046907  0.008899       8        1   5.036966
# 13    -0.093069  0.128669       9        1   4.416480
# 8     -0.064810  0.126633      10        1   4.414421
# 0      0.177109 -0.088234      11        1   3.934842
# 18    -0.309448 -0.297825      12        1   3.923267
# 12     0.198918 -0.122282      13        1   3.457412
# 7      0.008730 -0.007742      14        1   2.925112
# 10     0.021370  0.041089      15        1   2.465674
# 3     -0.065288 -0.157538      16        1   1.749781
# ...

# %%
SUBJECTS = ["nsubj", "nsubjpass", "csubj", "csubjpass", "agent", "expl"]
OBJECTS = ["dobj", "dative", "attr", "oprd"]

def subjects_from_conjunction(subjects):
    additional_subjects= []
    for subject in subjects:
        # get everything to the right of the subject
        rights = list(subject.rights)
        right_dendencies = {token.lower_ for token in rights}
        if "and" in right_dendencies:
            additional_subjects.extend([token for token in rights if token.dep_ in SUBJECTS or token.pos_ == "NOUN"])
            if len(additional_subjects) > 0:
                additional_subjects.extend(subjects_from_conjunction(additional_subjects))
#         print("Additional Subjects:", additional_subjects)
    return additional_subjects

def objects_from_Conjunctions(objects):
    additional_objects= []
    for object in objects:
        # get everything to the right of the object
        rights = list(object.rights)
        right_dendencies = {token.lower_ for token in rights}
        if "and" in right_dendencies:
            additional_objects.extend([token for token in rights if token.dep_ in OBJECTS or token.pos_ == "NOUN"])
            if len(additional_objects) > 0:
                additional_objects.extend(objects_from_Conjunctions(additional_objects))
#     print("Objects from Conjunctions:", additional_objects)
    return additional_objects

def findSubjects(token):
    head = token.head
    while head.pos_ != "VERB" and head.pos_ != "NOUN" and head.head != head:
        head = head.head
    if head.pos_ == "VERB":
#         print("verb heads:", head)
        subjects = [tok for tok in head.lefts if tok.dep_ == "SUB"]
        if len(subjects) > 0:
            verb_is_negated = isNegated(head)
            subjects.extend(subjects_from_conjunction(subjects))
            return subjects, verb_is_negated
        elif head.head != head:
            return findSubjects(head)
    elif head.pos_ == "NOUN":
#         print("noun heads:", head)
        return [head], isNegated(token)
    return [], False

def isNegated(token):
    negations = {"no", "not", "n't", "never", "none", "dont"}
    for dep in list(token.lefts) + list(token.rights):
        if dep.lower_ in negations:
            return True
    return False

def objects_from_prepositions(dependencies):
    objects = []
    for dependency in dependencies:
        if dependency.pos_ == "ADP" and dependency.dep_ == "prep":
            objects.extend([token for token in dependency.rights if token.dep_  in OBJECTS or 
                                                     (token.pos_ == "PRON" and token.lower_ == "me")
                        ])
#     print("objects from prepositions:", objects)
    return objects


def all_subjects(verb):
    verbNegated = isNegated(verb)
    subjects = [token for token in verb.lefts if (token.dep_).lower() in SUBJECTS and token.pos_ != "DET"]
#     print()
#     print(verb, subjects)
    if len(subjects) > 0:
        subjects.extend(subjects_from_conjunction(subjects))
    else:
        foundSubjects, verbNegated = findSubjects(verb)
        subjects.extend(foundSubjects)
#     print("subjects, verb negated:", subjects, verbNegated)
    return subjects, verbNegated

def all_objects(v):
    # A right-child of the token= rights
    rights = list(v.rights)
    objetcs = [tok.head.orth_ for tok in rights if (tok.dep_).lower() in OBJECTS]
    objects = [tok for tok in rights if (tok.dep_).lower() in OBJECTS]
    
#     print("objects:", objects)
    objetcs.extend(objects_from_prepositions(rights))
    if len(objects) > 0:
        objetcs.extend(objects_from_Conjunctions(objects))
    return v, objects

def summarize(tokens):
    summary_ = []
    summary = []
    verbs = [token for token in tokens if token.pos_ == "VERB" and token.dep_ != "aux"]
#     print("verbs:", verbs)
    for verb in verbs:
        subjects, verbNegated = all_subjects(verb)
#         if len(subjects)>0:
#             print("\nSubjects, Verb ,Negations:", subjects, verb, verbNegated)

        # evaluate verb only if there are subjects
        if len(subjects) > 0:
            verb, objects = all_objects(verb)
#             print("Verb, Verb Negations:", verb, objects)
            for subject in subjects:
                for object in objects:
                    objNegated = isNegated(object)
                    summary_.append((subject.lower_, "NOT " + verb.lower_ if verbNegated or 
                                                                 objNegated 
                                                                else verb.lower_, object.lower_
                                ))
    for tuple_item in summary_:
        summary_item = " ".join(item for item in tuple_item)
        summary.append(summary_item)
    return ".".join(sentence for sentence in summary)

# %%
# !python -m spacy download en_core_web_lg
# Out:
# ...
#      |████████████████████████████████| 827.9MB 1.1MB/s
# ...
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-cp37-none-any.whl size=829180944 sha256=40d4f2b7fcac32e347d0fba2c4a22154c6e06681f0c0d3cceb45ed2797c2520d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-25_mi2f8/wheels/2a/c1/a6/fc7a877b1efca9bc6a089d6f506f16d3868408f9ff89f8dbfc
# Successfully built en-core-web-lg
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
#restart runtime
import os
os.kill(os.getpid(), 9)

# %%
import spacy
nlp = spacy.load('en_core_web_lg')

# %%
text = 'resolution reality get certified save extended end january go corrective exercise specialist program end january go set resolution motion save ace specialist program go new cec club unlimited cecs entire year join cart sign sign ace fitness certification education resource certification browse certification personal trainer group fitness instructor health coach medical exercise specialist certificate peer fitness trainer support certification schedule exam ace study coach accreditation military support financial assistance resolution reality save study program extended end january save see promotion education resource browse professional resource continuing education cec club online course specialist program workshop event live webinars magazine quiz ecredits ace approved course career support certified™ research study ace insight blog career center referral reward program recertification healthcare professional program benefit ace lifestyle ace healthy living blog exercise library tool calculator find ace pro healthy recipe help client find relief pain save corrective exercise specialist program end january start set resolution motion enjoy ace specialist program save new cec club unlimited cecs entire year month join see promotion mission ace glance advocacy business partnership idea world scholarship culture team career press room contact u resolution reality save study program extended end january save help client find relief pain save corrective exercise specialist program end january start set resolution motion enjoy ace specialist program save new cec club unlimited cecs entire year month join see promotion live webinars view cecs continuing education topic approved continuing education topic search continuing education continuing education topic cec club new course sale personal small group training view anatomy kinesiology physiology balance training bodyweight training cardiorespiratory program design core training endurance sport fitness postural assessment flexibility training functional training hiit homebased movementbased training running sport performance strength training triathlon nutrition view eating disorder nutrition health wellness sport nutrition supplement ergogenic aid weight loss weight management behavior change view lifestyle wellness coaching motivation adherence rapport communication personal training program design view rapport functional movement resistance training cardiorespiratory training business view business strategy planning career planning facility operation legal management sale marketing group fitness view aquatic fitness barre boot camp cardiorespiratory program design core training dancebased program functional training group strength instructing cueing choreography kickboxing boxing martial art mma movementbased training prechoreographed program steptraditional aerobics walking program mindbody view mind body yoga special population condition view cancer injury prevention post rehab metabolic disease diabetes myofascial release older adult orthopedic condition overweight obesity prepost natal woman fitness youth specialized equipment training view kettlebell training olympic lifting advocacy fire police tactical training view peer fitness trainer iaffiafc approved approved aama acsm afaa cbrn cdr ci ichwc nasm ncbde ncsf nfpt ymca upcoming fitness webinars free live webinars—broadcast ace studio san diego ca—provide unique opportunity engage realtime top expert field ace american council exercise weight management changing behavior change life pm pst free learn ace american council exercise exercise strategy client cardiovascular disease pm pst free learn ace american council exercise fitness nutrition expert weigh pm pdt free learn ace american council exercise stress management reduce stress better health pm pdt free learn ace american council exercise small group training program design healthier community pm pdt free learn ace american council exercise aging exercise reduce cognitive decline physical activity pm pdt free learn recorded live webinars every live webinar recorded made available day following broadcast online course worth cec cecs ace american council exercise guide replacing processed food whole food learn cecs ace american council exercise working cancer patient learn cecs ace american council exercise training youth athlete learn cecs ace american council exercise busy day call hiit learn cecs ace american council exercise integrated exercise implementation learn cecs ace american council exercise low back health begin core learn cecs ace american council exercise well good boost bottom line social impact learn cecs ace american council exercise mental physical exercise longterm stress management learn cecs ace american council exercise mindful eating future eating weight loss learn cecs ace american council exercise got wrong nutrition recommendation heart health learn cecs ace american council exercise business small group training learn cecs ace american council exercise making walkable community norm learn search continuing education view cecs continuing education topic cec club new course sale personal small group training view anatomy kinesiology physiology balance training bodyweight training cardiorespiratory program design core training endurance sport fitness postural assessment flexibility training functional training hiit homebased movementbased training running sport performance strength training triathlon nutrition view eating disorder nutrition health wellness sport nutrition supplement ergogenic aid weight loss weight management behavior change view lifestyle wellness coaching motivation adherence rapport communication personal training program design view rapport functional movement resistance training cardiorespiratory training business view business strategy planning career planning facility operation legal management sale marketing group fitness view aquatic fitness barre boot camp cardiorespiratory program design core training dancebased program functional training group strength instructing cueing choreography kickboxing boxing martial art mma movementbased training prechoreographed program steptraditional aerobics walking program mindbody view mind body yoga special population condition view cancer injury prevention post rehab metabolic disease diabetes myofascial release older adult orthopedic condition overweight obesity prepost natal woman fitness youth specialized equipment training view kettlebell training olympic lifting advocacy fire police tactical training view peer fitness trainer iaffiafc approved aama acsm afaa cbrn cdr ci ichwc nasm ncbde ncsf nfpt ymca share keep cutting edge receive unique offer information specialist program workshop free webinars enter email yes id like receive information special offer specialist program workshop free webinars subscribe load past webinars brand anthem ace team advocacy press room career professional continuing education specialist program recertification career center certified ™ research study certification personal trainer group fitness instructor health coach medical exercise specialist additional ace certification resource ace healthy living blog exercise library tool calculator find ace pro store legal term use privacy policy return policy sitemap cookie preference contact u american council exercise paramount drive san diego california facebook twitter instagram pinterest linkedin copyright© american council exercise right reserved',

# %%
text = summarize(nlp(text))
print(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ca2cd56ebb82> in <module>()
# ----> 1 text = summarize(nlp(text))
#       2 print(text)
#
# /usr/local/lib/python3.7/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     429                 Errors.E088.format(length=len(text), max_length=self.max_length)
#     430             )
# --> 431         doc = self.make_doc(text)
#     432         if component_cfg is None:
#     433             component_cfg = {}
#
# /usr/local/lib/python3.7/dist-packages/spacy/language.py in make_doc(self, text)
#     455
#     456     def make_doc(self, text):
# --> 457         return self.tokenizer(text)
#     458
#     459     def _format_docs_and_golds(self, docs, golds):
#
# TypeError: Argument 'string' has incorrect type (expected str, got tuple)
