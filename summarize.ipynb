# %%
pip install nltk==3.4.5

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
# !pip install sumy

# %%
original_text= '         AMERICAN ACADEMY OF CLINICAL PSYCHIATRISTS                    forgot password?    LOGIN         I want to join AACP  or renew an existing membership                      American Academy of Clinical Psychiatrists  Home  About   About AACP  Board of Directors  Bylaws    Meetings and Events   CP/AACP Psychiatry Update  CP/AACP Psychiatry Update Encore Presentation  CP/AACP Focus on Neuropsychiatry    Winokur Award  AACP Membership   Membership Benefits  Member Search  Membership Application  Login  AACP Meeting Video and Audio    Contact   Annals of Clinical Psychiatry  Current Issue  All Issues  About Annals   Annals Mission Statement  Editor-in-Chief  Editorial Board  Reprints & Permissions  Instructions for Authors    Subscribe                Privacy Policies | Terms of Use    Copyright © 2019 AACP. All rights reserved.        Exploring Asian American attitudes regarding mental health treatment in primary care: A qualitative study      BACKGROUND : In this exploratory study, we examined attitudes regarding mental health treatment among 10 Asian American patients in an urban primary care setting to better understand contextual barriers to care.  METHODS : Ten semi-structured telephone interviews were conducted with Asian Americans recruited from primary care practices in an urban medi­cal center.  RESULTS : The study’s qualitative data suggest that focusing on specific cul­tural concerns is essential for increasing mental health access for Asian Americans. Although few participants initially expressed interest in a cul­turally focused mental health program themselves, when phrased as being part of their primary care practice, 8 expressed interest. Furthermore, most felt that the program could help family or friends. Many participants preferred to seek care initially from social systems and alternative and complementary medicine before seeking psychiatric care.  CONCLUSIONS : Because Asian Americans face notable barriers to seek­ing mental health treatment, addressing cultural concerns by providing culturally sensitive care could help make mental health treatment more acceptable, particularly among less acculturated individuals. To our knowledge, this is the first qualitative study exploring barriers to Asian Americans accessing integrated mental health services in primary care.     Purchase this article:  PURCHASE FOR $12  For unlimited access to all issues and articles:   SUBSCRIBE NOW  LOG IN TO ACCOUNT                 Privacy Policies | Terms of Use    Copyright © 2019 AACP. All rights reserved.                '

# %%
import re

def clean_text(x):
    x = " ".join(x.split())
    x= " ".join((" ".join(x.split("[**"))).split("**]"))
    x = re.sub(r"\([^()]*\)", "", x)
    key_value_strip =(x.split(":"))
    ##remove all sub strings which have a length lesser than 50 characters
    string = " ".join([sub_unit for sub_unit in key_value_strip if len(sub_unit)>50])
    x = re.sub(r"(\d+)+(\.|\))", "", string)## remove all serialization eg 1. 1)
    x = re.sub(r"(\*|\?|=)+", "", x) ##removing all *, ? and =
    x = re.sub(r"\b(\w+)( \1\b)+", r"\1", x) ## removing consecutive dupicate words
    x = x.replace("FOLLOW UP", "FOLLOWUP")
    x = x.replace("FOLLOW-UP", "FOLLOWUP")
    x = re.sub(r"(\b)(f|F)(irst)(\b)?[\d\-\d]*(\s)*(\b)?(n|N)(ame)[\d\-\d]*(\s)*[\d\-\d]*(\b)","",x)##remove firstname
    x = re.sub(r"(\b)(l|L)(ast)(\b)?[\d\-\d]*(\s)*(\b)?(n|N)(ame)[\d\-\d]*(\s)*[\d\-\d]*(\b)", "", x)
    x = re.sub(r"(\b)(d|D)\.?(r|R)\.?(\b)", "", x) #remove Dr abreviation
    x = re.sub(r"([^A-Za-z0-9\s](\s)){2,}", "", x)##remove consecutive punctuations
    

    return(x.replace("  ", " "))

# %%
text = clean_text(original_text)
text
# Out:
# 'AMERICAN ACADEMY OF CLINICAL PSYCHIATRISTS forgot password LOGIN I want to join AACP or renew an existing membership American Academy of Clinical Psychiatrists Home About AACP Board of Directors Bylaws Meetings and Events CP/AACP Psychiatry Update CP/AACP Psychiatry Update Encore Presentation CP/AACP Focus on Neuropsychiatry Winokur Award AACP Membership Benefits Member Search Membership Application Login AACP Meeting Video and Audio Contact Annals of Clinical Psychiatry Current Issue All Issues About Annals Mission Statement Editor-in-Chief Editorial Board Reprints & Permissions Instructions for Authors Subscribe Privacy Policies | Terms of Use Copyright © 2019 AACP. All rights reserved. Exploring Asian American attitudes regarding mental health treatment in primary care In this exploratory study, we examined attitudes regarding mental health treatment among 10 Asian American patients in an urban primary care setting to better understand contextual barriers to care. METHODS  Ten se
# ...

# %%
import nltk
words = set(nltk.corpus.words.words())

sent = text
" ".join(w for w in nltk.wordpunct_tokenize(sent) \
         if w.lower() in words or not w.isalpha())
# Out:
# 'ACADEMY OF CLINICAL forgot password LOGIN I want to join or renew an membership Academy of Clinical Home About Board of and / Psychiatry Update / Psychiatry Update Encore Presentation / Focus on Neuropsychiatry Award Membership Member Search Membership Application Login Meeting Video and Audio Contact Annals of Clinical Psychiatry Current Issue All About Annals Mission Statement Editor - in - Chief Editorial Board & for Subscribe Privacy | of Use Copyright © 2019 . All reserved . Exploring regarding mental health treatment in primary care In this exploratory study , we regarding mental health treatment among 10 in an urban primary care setting to better understand contextual to care . Ten semi - structured telephone were with from primary care in an urban \xad cal center . The study ’ s qualitative data suggest that on specific \xad is essential for increasing mental health access for . Although few initially expressed interest in a \xad mental health program themselves , when as be
# ...

# %%
# Importing the parser and tokenizer
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer

# %%
# Import the LexRank summarizer
from sumy.summarizers.lex_rank import LexRankSummarizer

# %%
# Initializing the parser
my_parser = PlaintextParser.from_string(sent,Tokenizer('english'))

# %%
# Creating a summary of 3 sentences.
lex_rank_summarizer = LexRankSummarizer()
lexrank_summary = lex_rank_summarizer(my_parser.document,sentences_count=3)

# Printing the summary
for sentence in lexrank_summary:
  print(sentence)
# Out:
# Exploring Asian American attitudes regarding mental health treatment in primary care In this exploratory study, we examined attitudes regarding mental health treatment among 10 Asian American patients in an urban primary care setting to better understand contextual barriers to care.
# To our knowledge, this is the first qualitative study exploring barriers to Asian Americans accessing integrated mental health services in primary care.
# Purchase this article PURCHASE FOR $12 For unlimited access to all issues and articles SUBSCRIBE NOW LOG IN TO ACCOUNT Privacy Policies | Terms of Use Copyright © 2019 AACP.

# %%
new_text = 'How many species of animals are there in Russia and in the US, and where are the biggest oceans?'
tokens = [stemmer.stem(token) for token in tokenizer.tokenize(new_text.lower()) if token not in stopwords_fr]
lda_model[dictionary_LDA.doc2bow(tokens)]
